# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
# tf.__version__

# %%
import zipfile,os
 
base_dir = '/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize'
train_dir = os.path.join(base_dir, 'Mata')

# %%
os.listdir('/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize/Mata')
# Out:
# ['Konjungtivitis', 'Bintitan', 'Subconjunctival-Bleeding']

# %%
# Class Names
root_path = '/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize/Mata/'
class_names = sorted(os.listdir(root_path))
n_classes = len(class_names)

# Class Distribution
class_dis = [len(os.listdir(root_path + name)) for name in class_names]

# Show
print(f"Total Number of Classes : {n_classes} \nClass Names : {class_names}")
# Out:
# Total Number of Classes : 3
# Class Names : ['Bintitan', 'Konjungtivitis', 'Subconjunctival-Bleeding']

# %%
print(len(os.listdir('/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize/Mata/Bintitan')))
print(len(os.listdir('/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize/Mata/Konjungtivitis')))
print(len(os.listdir('/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize/Mata/Subconjunctival-Bleeding')))
# Out:
# 153
# 170
# 187

# %% [markdown]
# # Preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
image_datagen = ImageDataGenerator(
                    # rescale=1./255,
                    rotation_range=10,
                    horizontal_flip=True,
                    shear_range = 0.1,
                    fill_mode = 'nearest',
                    validation_split = 0.2,
                    width_shift_range=0.1,
                    height_shift_range=0.1,)

# Rescale kalo resolusi gambar seragam
# Ga perlu rescale kalo resolusi beda-beda

train_generator = image_datagen.flow_from_directory(
        train_dir,
        subset='training',
        target_size=(300, 300),
        batch_size=32,
        class_mode='categorical'
        )

validation_generator = image_datagen.flow_from_directory(
        train_dir,
        subset='validation',
        target_size=(300, 300),
        batch_size=32,
        class_mode='categorical'
        )
# Out:
# Found 409 images belonging to 3 classes.
# Found 101 images belonging to 3 classes.

# %% [markdown]
# # Transfer Learning

# %%
from tensorflow.keras.layers import Input , Dense , Flatten , GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.models import Sequential

transfer = tf.keras.applications.EfficientNetB4(
              input_shape=(300,300,3),
              include_top=False,
              weights='imagenet',
)
transfer.trainable = False
transfer.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 4s 0us/step
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 300, 300, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 300, 300, 3)  7           ['rescaling[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 300, 300, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 301, 301, 3)  0           ['tf.math.truediv[0][0]']
#
#  stem_conv (Conv2D)             (None, 150, 150, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 150, 150, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 150, 150, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 150, 150, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 150, 150, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 150, 150, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 150, 150, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 150, 150, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 150, 150, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 150, 150, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 150, 150, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 150, 150, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 150, 150, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 150, 150, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 150, 150, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 150, 150, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 150, 150, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 150, 150, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 150, 150, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 150, 150, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 151, 151, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 75, 75, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 75, 75, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 75, 75, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 75, 75, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 75, 75, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 75, 75, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 75, 75, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 75, 75, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 75, 75, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 75, 75, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 75, 75, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 75, 75, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 75, 75, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 75, 75, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 75, 75, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 75, 75, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 75, 75, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 75, 75, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 75, 75, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 75, 75, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 75, 75, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 75, 75, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 75, 75, 192)  1728       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 75, 75, 192)  768        ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 75, 75, 192)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 75, 75, 192)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 75, 75, 32)   6144        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 75, 75, 32)  128         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 75, 75, 32)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 75, 75, 32)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 75, 75, 192)  6144        ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 75, 75, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 75, 75, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 79, 79, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 38, 38, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 38, 38, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 38, 38, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 38, 38, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 38, 38, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 38, 38, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 38, 38, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 38, 38, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 38, 38, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 38, 38, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 38, 38, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 38, 38, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 38, 38, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 38, 38, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 38, 38, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 38, 38, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 38, 38, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 38, 38, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 38, 38, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 38, 38, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 38, 38, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 38, 38, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 38, 38, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 38, 38, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 38, 38, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 38, 38, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 38, 38, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 38, 38, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 38, 38, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 38, 38, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 38, 38, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 38, 38, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 38, 38, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 38, 38, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 38, 38, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 38, 38, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 38, 38, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 38, 38, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 38, 38, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 38, 38, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 38, 38, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 38, 38, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 39, 39, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 19, 19, 336)  3024       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 19, 19, 336)  1344       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 19, 19, 336)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 19, 19, 336)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 19, 19, 112)  37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 19, 19, 112)  448        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 19, 19, 672)  75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 19, 19, 672)  2688       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 19, 19, 672)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 19, 19, 672)  6048       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 19, 19, 672)  2688       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 19, 19, 672)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 19, 19, 672)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 19, 19, 112)  75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 19, 19, 112)  448        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 19, 19, 112)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 19, 19, 112)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 19, 19, 672)  75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 19, 19, 672)  2688       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 19, 19, 672)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 19, 19, 672)  6048       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 19, 19, 672)  2688       ['block4c_dwconv[0][0]']
#  )
#
# ...
#  block6g_expand_activation (Act  (None, 10, 10, 1632  0          ['block6g_expand_bn[0][0]']
#  ivation)                       )
#
#  block6g_dwconv (DepthwiseConv2  (None, 10, 10, 1632  40800      ['block6g_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6g_bn (BatchNormalization  (None, 10, 10, 1632  6528       ['block6g_dwconv[0][0]']
#  )                              )
#
#  block6g_activation (Activation  (None, 10, 10, 1632  0          ['block6g_bn[0][0]']
#  )                              )
#
#  block6g_se_squeeze (GlobalAver  (None, 1632)        0           ['block6g_activation[0][0]']
#  agePooling2D)
#
#  block6g_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6g_se_squeeze[0][0]']
#
#  block6g_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multiply)   (None, 10, 10, 1632  0           ['block6g_activation[0][0]',
#                                 )                                 'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv2D)  (None, 10, 10, 272)  443904      ['block6g_se_excite[0][0]']
#
#  block6g_project_bn (BatchNorma  (None, 10, 10, 272)  1088       ['block6g_project_conv[0][0]']
#  lization)
#
#  block6g_drop (Dropout)         (None, 10, 10, 272)  0           ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)              (None, 10, 10, 272)  0           ['block6g_drop[0][0]',
#                                                                   'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2D)   (None, 10, 10, 1632  443904      ['block6g_add[0][0]']
#                                 )
#
#  block6h_expand_bn (BatchNormal  (None, 10, 10, 1632  6528       ['block6h_expand_conv[0][0]']
#  ization)                       )
#
#  block6h_expand_activation (Act  (None, 10, 10, 1632  0          ['block6h_expand_bn[0][0]']
#  ivation)                       )
#
#  block6h_dwconv (DepthwiseConv2  (None, 10, 10, 1632  40800      ['block6h_expand_activation[0][0]
#  D)                             )                                ']
#
#  block6h_bn (BatchNormalization  (None, 10, 10, 1632  6528       ['block6h_dwconv[0][0]']
#  )                              )
#
#  block6h_activation (Activation  (None, 10, 10, 1632  0          ['block6h_bn[0][0]']
#  )                              )
#
#  block6h_se_squeeze (GlobalAver  (None, 1632)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 10, 10, 1632  0           ['block6h_activation[0][0]',
#                                 )                                 'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 10, 10, 272)  443904      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 10, 10, 272)  1088       ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 10, 10, 272)  0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 10, 10, 272)  0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 10, 10, 1632  443904      ['block6h_add[0][0]']
#                                 )
#
#  block7a_expand_bn (BatchNormal  (None, 10, 10, 1632  6528       ['block7a_expand_conv[0][0]']
#  ization)                       )
#
#  block7a_expand_activation (Act  (None, 10, 10, 1632  0          ['block7a_expand_bn[0][0]']
#  ivation)                       )
#
#  block7a_dwconv (DepthwiseConv2  (None, 10, 10, 1632  14688      ['block7a_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7a_bn (BatchNormalization  (None, 10, 10, 1632  6528       ['block7a_dwconv[0][0]']
#  )                              )
#
#  block7a_activation (Activation  (None, 10, 10, 1632  0          ['block7a_bn[0][0]']
#  )                              )
#
#  block7a_se_squeeze (GlobalAver  (None, 1632)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 10, 10, 1632  0           ['block7a_activation[0][0]',
#                                 )                                 'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 10, 10, 448)  731136      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 10, 10, 448)  1792       ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 10, 10, 2688  1204224     ['block7a_project_bn[0][0]']
#                                 )
#
#  block7b_expand_bn (BatchNormal  (None, 10, 10, 2688  10752      ['block7b_expand_conv[0][0]']
#  ization)                       )
#
#  block7b_expand_activation (Act  (None, 10, 10, 2688  0          ['block7b_expand_bn[0][0]']
#  ivation)                       )
#
#  block7b_dwconv (DepthwiseConv2  (None, 10, 10, 2688  24192      ['block7b_expand_activation[0][0]
#  D)                             )                                ']
#
#  block7b_bn (BatchNormalization  (None, 10, 10, 2688  10752      ['block7b_dwconv[0][0]']
#  )                              )
#
#  block7b_activation (Activation  (None, 10, 10, 2688  0          ['block7b_bn[0][0]']
#  )                              )
#
#  block7b_se_squeeze (GlobalAver  (None, 2688)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2688)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 112)    301168      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2688)   303744      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 10, 10, 2688  0           ['block7b_activation[0][0]',
#                                 )                                 'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 10, 10, 448)  1204224     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 10, 10, 448)  1792       ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 10, 10, 448)  0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 10, 10, 448)  0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 10, 10, 1792  802816      ['block7b_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 10, 10, 1792  7168        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 10, 10, 1792  0           ['top_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 17,673,823
# Trainable params: 0
# Non-trainable params: 17,673,823
# __________________________________________________________________________________________________

# %%
model = tf.keras.models.Sequential([
    transfer,
    tf.keras.layers.GlobalAveragePooling2D(),
    #Flatten
    tf.keras.layers.Flatten(),
    
    # Fully
    tf.keras.layers.Dense(1280, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'), 
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])
# model.add(transfer)
# model.add(GlobalAveragePooling2D())
# model.add(Dropout(0.2))
# model.add(Dense(4,activation="softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 10, 10, 1792)     17673823
#
#  global_average_pooling2d_1   (None, 1792)             0
#  (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 1792)              0
#
#  dense_3 (Dense)             (None, 1280)              2295040
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 128)               163968
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 20,133,218
# Trainable params: 2,459,395
# Non-trainable params: 17,673,823
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=2e-3, momentum=0.9),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

reduce = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=10,
    verbose=0,
    mode='auto',
    min_delta=0.0001,
    cooldown=0,
    min_lr=0,
)

class stopTraining(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy') > 0.997 and logs.get('val_accuracy') < 100):
      print('Val Akurasi telah melebihi 99%')
      self.model.stop_training = True

early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='auto')
checkpoint = ModelCheckpoint("/content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5", monitor='val_accuracy', verbose=1, save_best_only=True)
callBack = stopTraining()

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
   print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
# latih model dengan model.fit 
history = model.fit(
      train_generator,                    
      epochs=1000,
      validation_data=validation_generator, 
      callbacks = [checkpoint, early, callBack],
      verbose=2
)
# Out:
# Epoch 1/1000
#
# Epoch 1: val_accuracy improved from -inf to 0.42574, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 291s - loss: 1.0954 - accuracy: 0.3594 - val_loss: 1.0702 - val_accuracy: 0.4257 - 291s/epoch - 22s/step
# Epoch 2/1000
#
# Epoch 2: val_accuracy improved from 0.42574 to 0.48515, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 13s - loss: 1.0511 - accuracy: 0.4474 - val_loss: 1.0249 - val_accuracy: 0.4851 - 13s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_accuracy improved from 0.48515 to 0.59406, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 13s - loss: 1.0191 - accuracy: 0.4768 - val_loss: 0.9638 - val_accuracy: 0.5941 - 13s/epoch - 1s/step
# Epoch 4/1000
#
# Epoch 4: val_accuracy did not improve from 0.59406
# 13/13 - 12s - loss: 0.9682 - accuracy: 0.5697 - val_loss: 0.9454 - val_accuracy: 0.5446 - 12s/epoch - 941ms/step
# Epoch 5/1000
#
# Epoch 5: val_accuracy did not improve from 0.59406
# 13/13 - 12s - loss: 0.9497 - accuracy: 0.5697 - val_loss: 0.9006 - val_accuracy: 0.5347 - 12s/epoch - 926ms/step
# Epoch 6/1000
#
# Epoch 6: val_accuracy did not improve from 0.59406
# 13/13 - 12s - loss: 0.9289 - accuracy: 0.5648 - val_loss: 0.8863 - val_accuracy: 0.5842 - 12s/epoch - 928ms/step
# Epoch 7/1000
#
# Epoch 7: val_accuracy did not improve from 0.59406
# 13/13 - 12s - loss: 0.9049 - accuracy: 0.5746 - val_loss: 0.8673 - val_accuracy: 0.5743 - 12s/epoch - 938ms/step
# Epoch 8/1000
#
# Epoch 8: val_accuracy improved from 0.59406 to 0.65347, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.8833 - accuracy: 0.5966 - val_loss: 0.8153 - val_accuracy: 0.6535 - 14s/epoch - 1s/step
# Epoch 9/1000
#
# Epoch 9: val_accuracy improved from 0.65347 to 0.66337, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.8497 - accuracy: 0.6308 - val_loss: 0.8250 - val_accuracy: 0.6634 - 14s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_accuracy improved from 0.66337 to 0.69307, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 16s - loss: 0.8300 - accuracy: 0.6528 - val_loss: 0.7870 - val_accuracy: 0.6931 - 16s/epoch - 1s/step
# Epoch 11/1000
#
# Epoch 11: val_accuracy did not improve from 0.69307
# 13/13 - 12s - loss: 0.8453 - accuracy: 0.6259 - val_loss: 0.8178 - val_accuracy: 0.5842 - 12s/epoch - 959ms/step
# Epoch 12/1000
#
# Epoch 12: val_accuracy did not improve from 0.69307
# 13/13 - 12s - loss: 0.7684 - accuracy: 0.6870 - val_loss: 0.8217 - val_accuracy: 0.5743 - 12s/epoch - 930ms/step
# Epoch 13/1000
#
# Epoch 13: val_accuracy did not improve from 0.69307
# 13/13 - 12s - loss: 0.7776 - accuracy: 0.6724 - val_loss: 0.8106 - val_accuracy: 0.6139 - 12s/epoch - 934ms/step
# Epoch 14/1000
#
# Epoch 14: val_accuracy did not improve from 0.69307
# 13/13 - 12s - loss: 0.7659 - accuracy: 0.6675 - val_loss: 0.7573 - val_accuracy: 0.6436 - 12s/epoch - 936ms/step
# Epoch 15/1000
#
# Epoch 15: val_accuracy did not improve from 0.69307
# 13/13 - 12s - loss: 0.7531 - accuracy: 0.6650 - val_loss: 0.7397 - val_accuracy: 0.6733 - 12s/epoch - 923ms/step
# Epoch 16/1000
#
# Epoch 16: val_accuracy did not improve from 0.69307
# 13/13 - 12s - loss: 0.7635 - accuracy: 0.6675 - val_loss: 0.7668 - val_accuracy: 0.6139 - 12s/epoch - 922ms/step
# Epoch 17/1000
#
# Epoch 17: val_accuracy improved from 0.69307 to 0.72277, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.7375 - accuracy: 0.6822 - val_loss: 0.7041 - val_accuracy: 0.7228 - 14s/epoch - 1s/step
# Epoch 18/1000
#
# Epoch 18: val_accuracy did not improve from 0.72277
# 13/13 - 12s - loss: 0.7119 - accuracy: 0.7066 - val_loss: 0.7163 - val_accuracy: 0.7228 - 12s/epoch - 944ms/step
# Epoch 19/1000
#
# Epoch 19: val_accuracy did not improve from 0.72277
# 13/13 - 12s - loss: 0.6817 - accuracy: 0.7115 - val_loss: 0.7532 - val_accuracy: 0.6238 - 12s/epoch - 921ms/step
# Epoch 20/1000
#
# Epoch 20: val_accuracy did not improve from 0.72277
# 13/13 - 12s - loss: 0.6582 - accuracy: 0.7335 - val_loss: 0.7022 - val_accuracy: 0.6733 - 12s/epoch - 924ms/step
# Epoch 21/1000
#
# Epoch 21: val_accuracy did not improve from 0.72277
# 13/13 - 12s - loss: 0.6695 - accuracy: 0.7115 - val_loss: 0.7141 - val_accuracy: 0.6931 - 12s/epoch - 923ms/step
# Epoch 22/1000
#
# Epoch 22: val_accuracy improved from 0.72277 to 0.73267, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.6990 - accuracy: 0.6919 - val_loss: 0.6553 - val_accuracy: 0.7327 - 14s/epoch - 1s/step
# Epoch 23/1000
#
# Epoch 23: val_accuracy did not improve from 0.73267
# 13/13 - 12s - loss: 0.6361 - accuracy: 0.7531 - val_loss: 0.6797 - val_accuracy: 0.6733 - 12s/epoch - 953ms/step
# Epoch 24/1000
#
# Epoch 24: val_accuracy improved from 0.73267 to 0.75248, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.6294 - accuracy: 0.7579 - val_loss: 0.6746 - val_accuracy: 0.7525 - 14s/epoch - 1s/step
# Epoch 25/1000
#
# Epoch 25: val_accuracy did not improve from 0.75248
# 13/13 - 13s - loss: 0.6540 - accuracy: 0.7139 - val_loss: 0.7027 - val_accuracy: 0.7426 - 13s/epoch - 1s/step
# Epoch 26/1000
#
# Epoch 26: val_accuracy did not improve from 0.75248
# 13/13 - 12s - loss: 0.5940 - accuracy: 0.7848 - val_loss: 0.6608 - val_accuracy: 0.7327 - 12s/epoch - 930ms/step
# Epoch 27/1000
#
# Epoch 27: val_accuracy improved from 0.75248 to 0.78218, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.6271 - accuracy: 0.7433 - val_loss: 0.6267 - val_accuracy: 0.7822 - 14s/epoch - 1s/step
# Epoch 28/1000
#
# Epoch 28: val_accuracy did not improve from 0.78218
# 13/13 - 12s - loss: 0.6066 - accuracy: 0.7408 - val_loss: 0.6635 - val_accuracy: 0.6733 - 12s/epoch - 958ms/step
# Epoch 29/1000
#
# Epoch 29: val_accuracy did not improve from 0.78218
# 13/13 - 12s - loss: 0.5810 - accuracy: 0.7653 - val_loss: 0.6563 - val_accuracy: 0.7327 - 12s/epoch - 931ms/step
# Epoch 30/1000
#
# Epoch 30: val_accuracy did not improve from 0.78218
# 13/13 - 12s - loss: 0.5668 - accuracy: 0.7824 - val_loss: 0.6019 - val_accuracy: 0.7228 - 12s/epoch - 918ms/step
# Epoch 31/1000
#
# Epoch 31: val_accuracy did not improve from 0.78218
# 13/13 - 12s - loss: 0.5416 - accuracy: 0.7848 - val_loss: 0.5811 - val_accuracy: 0.7822 - 12s/epoch - 922ms/step
# Epoch 32/1000
#
# Epoch 32: val_accuracy did not improve from 0.78218
# 13/13 - 12s - loss: 0.5224 - accuracy: 0.8068 - val_loss: 0.6054 - val_accuracy: 0.7426 - 12s/epoch - 922ms/step
# Epoch 33/1000
#
# Epoch 33: val_accuracy did not improve from 0.78218
# 13/13 - 12s - loss: 0.5065 - accuracy: 0.8020 - val_loss: 0.6081 - val_accuracy: 0.7723 - 12s/epoch - 919ms/step
# Epoch 34/1000
#
# Epoch 34: val_accuracy improved from 0.78218 to 0.79208, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.5126 - accuracy: 0.8044 - val_loss: 0.5733 - val_accuracy: 0.7921 - 14s/epoch - 1s/step
# Epoch 35/1000
#
# Epoch 35: val_accuracy did not improve from 0.79208
# 13/13 - 12s - loss: 0.4740 - accuracy: 0.8215 - val_loss: 0.6442 - val_accuracy: 0.7129 - 12s/epoch - 955ms/step
# Epoch 36/1000
#
# Epoch 36: val_accuracy did not improve from 0.79208
# 13/13 - 12s - loss: 0.5224 - accuracy: 0.7946 - val_loss: 0.6023 - val_accuracy: 0.7327 - 12s/epoch - 931ms/step
# Epoch 37/1000
#
# Epoch 37: val_accuracy improved from 0.79208 to 0.80198, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.4917 - accuracy: 0.7922 - val_loss: 0.5529 - val_accuracy: 0.8020 - 14s/epoch - 1s/step
# Epoch 38/1000
#
# Epoch 38: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4841 - accuracy: 0.8264 - val_loss: 0.5702 - val_accuracy: 0.7822 - 12s/epoch - 942ms/step
# Epoch 39/1000
#
# Epoch 39: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4636 - accuracy: 0.8289 - val_loss: 0.5961 - val_accuracy: 0.7525 - 12s/epoch - 922ms/step
# Epoch 40/1000
#
# Epoch 40: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4734 - accuracy: 0.8068 - val_loss: 0.5929 - val_accuracy: 0.7624 - 12s/epoch - 916ms/step
# Epoch 41/1000
#
# Epoch 41: val_accuracy did not improve from 0.80198
# 13/13 - 13s - loss: 0.4674 - accuracy: 0.8264 - val_loss: 0.5517 - val_accuracy: 0.7921 - 13s/epoch - 996ms/step
# Epoch 42/1000
#
# Epoch 42: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4461 - accuracy: 0.8460 - val_loss: 0.6264 - val_accuracy: 0.7129 - 12s/epoch - 920ms/step
# Epoch 43/1000
#
# Epoch 43: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4534 - accuracy: 0.8215 - val_loss: 0.5806 - val_accuracy: 0.7624 - 12s/epoch - 923ms/step
# Epoch 44/1000
#
# Epoch 44: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4148 - accuracy: 0.8435 - val_loss: 0.5362 - val_accuracy: 0.7624 - 12s/epoch - 923ms/step
# Epoch 45/1000
#
# Epoch 45: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4286 - accuracy: 0.8411 - val_loss: 0.5509 - val_accuracy: 0.7723 - 12s/epoch - 926ms/step
# Epoch 46/1000
#
# Epoch 46: val_accuracy did not improve from 0.80198
# 13/13 - 12s - loss: 0.4084 - accuracy: 0.8362 - val_loss: 0.5587 - val_accuracy: 0.7525 - 12s/epoch - 927ms/step
# Epoch 47/1000
#
# Epoch 47: val_accuracy improved from 0.80198 to 0.81188, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.4352 - accuracy: 0.8240 - val_loss: 0.5149 - val_accuracy: 0.8119 - 14s/epoch - 1s/step
# Epoch 48/1000
#
# Epoch 48: val_accuracy did not improve from 0.81188
# 13/13 - 12s - loss: 0.4224 - accuracy: 0.8362 - val_loss: 0.5982 - val_accuracy: 0.7525 - 12s/epoch - 939ms/step
# Epoch 49/1000
#
# Epoch 49: val_accuracy did not improve from 0.81188
# 13/13 - 12s - loss: 0.4109 - accuracy: 0.8484 - val_loss: 0.5357 - val_accuracy: 0.7822 - 12s/epoch - 926ms/step
# Epoch 50/1000
#
# Epoch 50: val_accuracy did not improve from 0.81188
# 13/13 - 12s - loss: 0.4071 - accuracy: 0.8484 - val_loss: 0.5448 - val_accuracy: 0.7426 - 12s/epoch - 919ms/step
# Epoch 51/1000
#
# Epoch 51: val_accuracy did not improve from 0.81188
# 13/13 - 12s - loss: 0.3698 - accuracy: 0.8631 - val_loss: 0.5733 - val_accuracy: 0.7624 - 12s/epoch - 915ms/step
# Epoch 52/1000
#
# Epoch 52: val_accuracy did not improve from 0.81188
# 13/13 - 12s - loss: 0.3729 - accuracy: 0.8704 - val_loss: 0.5763 - val_accuracy: 0.7624 - 12s/epoch - 930ms/step
# Epoch 53/1000
#
# Epoch 53: val_accuracy did not improve from 0.81188
# 13/13 - 12s - loss: 0.4034 - accuracy: 0.8460 - val_loss: 0.5834 - val_accuracy: 0.8119 - 12s/epoch - 925ms/step
# Epoch 54/1000
#
# Epoch 54: val_accuracy improved from 0.81188 to 0.82178, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.3875 - accuracy: 0.8313 - val_loss: 0.4794 - val_accuracy: 0.8218 - 14s/epoch - 1s/step
# Epoch 55/1000
#
# Epoch 55: val_accuracy did not improve from 0.82178
# 13/13 - 12s - loss: 0.4402 - accuracy: 0.8313 - val_loss: 0.5256 - val_accuracy: 0.7921 - 12s/epoch - 942ms/step
# Epoch 56/1000
#
# Epoch 56: val_accuracy did not improve from 0.82178
# 13/13 - 12s - loss: 0.3784 - accuracy: 0.8460 - val_loss: 0.5392 - val_accuracy: 0.7921 - 12s/epoch - 923ms/step
# Epoch 57/1000
#
# Epoch 57: val_accuracy did not improve from 0.82178
# 13/13 - 12s - loss: 0.3530 - accuracy: 0.8851 - val_loss: 0.5565 - val_accuracy: 0.7624 - 12s/epoch - 925ms/step
# Epoch 58/1000
#
# Epoch 58: val_accuracy did not improve from 0.82178
# 13/13 - 12s - loss: 0.3125 - accuracy: 0.8949 - val_loss: 0.6020 - val_accuracy: 0.7624 - 12s/epoch - 922ms/step
# Epoch 59/1000
#
# Epoch 59: val_accuracy did not improve from 0.82178
# 13/13 - 13s - loss: 0.3696 - accuracy: 0.8606 - val_loss: 0.5845 - val_accuracy: 0.7624 - 13s/epoch - 1s/step
# Epoch 60/1000
#
# Epoch 60: val_accuracy did not improve from 0.82178
# 13/13 - 12s - loss: 0.3478 - accuracy: 0.8704 - val_loss: 0.5494 - val_accuracy: 0.8119 - 12s/epoch - 917ms/step
# Epoch 61/1000
#
# Epoch 61: val_accuracy improved from 0.82178 to 0.83168, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.3415 - accuracy: 0.8680 - val_loss: 0.5033 - val_accuracy: 0.8317 - 14s/epoch - 1s/step
# Epoch 62/1000
#
# Epoch 62: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3298 - accuracy: 0.8704 - val_loss: 0.5813 - val_accuracy: 0.7228 - 12s/epoch - 928ms/step
# Epoch 63/1000
#
# Epoch 63: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3024 - accuracy: 0.8924 - val_loss: 0.5472 - val_accuracy: 0.7624 - 12s/epoch - 920ms/step
# Epoch 64/1000
#
# Epoch 64: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3452 - accuracy: 0.8533 - val_loss: 0.4813 - val_accuracy: 0.8317 - 12s/epoch - 926ms/step
# Epoch 65/1000
#
# Epoch 65: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3416 - accuracy: 0.8802 - val_loss: 0.4807 - val_accuracy: 0.7921 - 12s/epoch - 929ms/step
# Epoch 66/1000
#
# Epoch 66: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3197 - accuracy: 0.8900 - val_loss: 0.5375 - val_accuracy: 0.7921 - 12s/epoch - 922ms/step
# Epoch 67/1000
#
# Epoch 67: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2909 - accuracy: 0.8949 - val_loss: 0.5443 - val_accuracy: 0.7228 - 12s/epoch - 916ms/step
# Epoch 68/1000
#
# Epoch 68: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3151 - accuracy: 0.8778 - val_loss: 0.4856 - val_accuracy: 0.7723 - 12s/epoch - 927ms/step
# Epoch 69/1000
#
# Epoch 69: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3172 - accuracy: 0.8875 - val_loss: 0.5231 - val_accuracy: 0.8119 - 12s/epoch - 930ms/step
# Epoch 70/1000
#
# Epoch 70: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3037 - accuracy: 0.8875 - val_loss: 0.5349 - val_accuracy: 0.7624 - 12s/epoch - 919ms/step
# Epoch 71/1000
#
# Epoch 71: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2729 - accuracy: 0.9046 - val_loss: 0.4876 - val_accuracy: 0.7921 - 12s/epoch - 912ms/step
# Epoch 72/1000
#
# Epoch 72: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2551 - accuracy: 0.9169 - val_loss: 0.5330 - val_accuracy: 0.7921 - 12s/epoch - 921ms/step
# Epoch 73/1000
#
# Epoch 73: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2578 - accuracy: 0.9169 - val_loss: 0.5420 - val_accuracy: 0.7723 - 12s/epoch - 926ms/step
# Epoch 74/1000
#
# Epoch 74: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.3045 - accuracy: 0.8949 - val_loss: 0.5586 - val_accuracy: 0.7822 - 12s/epoch - 921ms/step
# Epoch 75/1000
#
# Epoch 75: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2717 - accuracy: 0.9169 - val_loss: 0.5257 - val_accuracy: 0.8119 - 12s/epoch - 916ms/step
# Epoch 76/1000
#
# Epoch 76: val_accuracy did not improve from 0.83168
# 13/13 - 13s - loss: 0.2564 - accuracy: 0.9291 - val_loss: 0.4654 - val_accuracy: 0.8218 - 13s/epoch - 1s/step
# Epoch 77/1000
#
# Epoch 77: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2580 - accuracy: 0.9144 - val_loss: 0.4803 - val_accuracy: 0.8020 - 12s/epoch - 926ms/step
# Epoch 78/1000
#
# Epoch 78: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2816 - accuracy: 0.8973 - val_loss: 0.5037 - val_accuracy: 0.7822 - 12s/epoch - 921ms/step
# Epoch 79/1000
#
# Epoch 79: val_accuracy did not improve from 0.83168
# 13/13 - 12s - loss: 0.2999 - accuracy: 0.8875 - val_loss: 0.4856 - val_accuracy: 0.8119 - 12s/epoch - 916ms/step
# Epoch 80/1000
#
# Epoch 80: val_accuracy improved from 0.83168 to 0.84158, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.2838 - accuracy: 0.8875 - val_loss: 0.4526 - val_accuracy: 0.8416 - 14s/epoch - 1s/step
# Epoch 81/1000
#
# Epoch 81: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2130 - accuracy: 0.9389 - val_loss: 0.5531 - val_accuracy: 0.7624 - 12s/epoch - 927ms/step
# Epoch 82/1000
#
# Epoch 82: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2690 - accuracy: 0.9071 - val_loss: 0.5347 - val_accuracy: 0.7624 - 12s/epoch - 908ms/step
# Epoch 83/1000
#
# Epoch 83: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2670 - accuracy: 0.9095 - val_loss: 0.4593 - val_accuracy: 0.8020 - 12s/epoch - 912ms/step
# Epoch 84/1000
#
# Epoch 84: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2264 - accuracy: 0.9144 - val_loss: 0.5342 - val_accuracy: 0.8020 - 12s/epoch - 914ms/step
# Epoch 85/1000
#
# Epoch 85: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2899 - accuracy: 0.8924 - val_loss: 0.5338 - val_accuracy: 0.7723 - 12s/epoch - 913ms/step
# Epoch 86/1000
#
# Epoch 86: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2181 - accuracy: 0.9169 - val_loss: 0.4793 - val_accuracy: 0.7723 - 12s/epoch - 908ms/step
# Epoch 87/1000
#
# Epoch 87: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2448 - accuracy: 0.9071 - val_loss: 0.4896 - val_accuracy: 0.8119 - 12s/epoch - 911ms/step
# Epoch 88/1000
#
# Epoch 88: val_accuracy did not improve from 0.84158
# 13/13 - 12s - loss: 0.2155 - accuracy: 0.9193 - val_loss: 0.5939 - val_accuracy: 0.8020 - 12s/epoch - 917ms/step
# Epoch 89/1000
#
# Epoch 89: val_accuracy improved from 0.84158 to 0.87129, saving model to /content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5
# 13/13 - 14s - loss: 0.2437 - accuracy: 0.9169 - val_loss: 0.4055 - val_accuracy: 0.8713 - 14s/epoch - 1s/step
# Epoch 90/1000
#
# Epoch 90: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2350 - accuracy: 0.9242 - val_loss: 0.5958 - val_accuracy: 0.7525 - 12s/epoch - 942ms/step
# Epoch 91/1000
#
# Epoch 91: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2392 - accuracy: 0.9267 - val_loss: 0.5586 - val_accuracy: 0.7525 - 12s/epoch - 916ms/step
# Epoch 92/1000
#
# Epoch 92: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2226 - accuracy: 0.9340 - val_loss: 0.5292 - val_accuracy: 0.8119 - 12s/epoch - 945ms/step
# Epoch 93/1000
#
# Epoch 93: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2468 - accuracy: 0.9046 - val_loss: 0.5883 - val_accuracy: 0.8020 - 12s/epoch - 919ms/step
# Epoch 94/1000
#
# Epoch 94: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2066 - accuracy: 0.9242 - val_loss: 0.5606 - val_accuracy: 0.7624 - 12s/epoch - 923ms/step
# Epoch 95/1000
#
# Epoch 95: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2183 - accuracy: 0.9291 - val_loss: 0.4806 - val_accuracy: 0.8020 - 12s/epoch - 917ms/step
# Epoch 96/1000
#
# Epoch 96: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2058 - accuracy: 0.9340 - val_loss: 0.4897 - val_accuracy: 0.8020 - 12s/epoch - 920ms/step
# Epoch 97/1000
#
# Epoch 97: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2194 - accuracy: 0.9120 - val_loss: 0.4796 - val_accuracy: 0.8317 - 12s/epoch - 912ms/step
# Epoch 98/1000
#
# Epoch 98: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2068 - accuracy: 0.9193 - val_loss: 0.5522 - val_accuracy: 0.7723 - 12s/epoch - 916ms/step
# Epoch 99/1000
#
# Epoch 99: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2495 - accuracy: 0.9169 - val_loss: 0.6006 - val_accuracy: 0.7822 - 12s/epoch - 926ms/step
# Epoch 100/1000
#
# Epoch 100: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1876 - accuracy: 0.9609 - val_loss: 0.5869 - val_accuracy: 0.7327 - 12s/epoch - 924ms/step
# Epoch 101/1000
#
# Epoch 101: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1833 - accuracy: 0.9511 - val_loss: 0.5871 - val_accuracy: 0.7822 - 12s/epoch - 920ms/step
# Epoch 102/1000
#
# Epoch 102: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1932 - accuracy: 0.9291 - val_loss: 0.4806 - val_accuracy: 0.8218 - 12s/epoch - 922ms/step
# Epoch 103/1000
#
# Epoch 103: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1869 - accuracy: 0.9340 - val_loss: 0.5444 - val_accuracy: 0.7624 - 12s/epoch - 920ms/step
# Epoch 104/1000
#
# Epoch 104: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1660 - accuracy: 0.9413 - val_loss: 0.4503 - val_accuracy: 0.8119 - 12s/epoch - 915ms/step
# Epoch 105/1000
#
# Epoch 105: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1825 - accuracy: 0.9389 - val_loss: 0.4843 - val_accuracy: 0.8317 - 12s/epoch - 909ms/step
# Epoch 106/1000
#
# Epoch 106: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2065 - accuracy: 0.9267 - val_loss: 0.5680 - val_accuracy: 0.7822 - 12s/epoch - 912ms/step
# Epoch 107/1000
#
# Epoch 107: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.2109 - accuracy: 0.9169 - val_loss: 0.5703 - val_accuracy: 0.7921 - 12s/epoch - 908ms/step
# Epoch 108/1000
#
# Epoch 108: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1614 - accuracy: 0.9560 - val_loss: 0.5077 - val_accuracy: 0.7723 - 12s/epoch - 905ms/step
# Epoch 109/1000
#
# Epoch 109: val_accuracy did not improve from 0.87129
# 13/13 - 12s - loss: 0.1774 - accuracy: 0.9340 - val_loss: 0.5378 - val_accuracy: 0.7624 - 12s/epoch - 915ms/step
# Epoch 109: early stopping

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(16, 5))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Unfreezing
transfer.trainable = True

for layer in transfer.layers[:-10]:
    layer.trainable = False
        
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 10, 10, 1792)     17673823
#
#  global_average_pooling2d_1   (None, 1792)             0
#  (GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 1792)              0
#
#  dense_3 (Dense)             (None, 1280)              2295040
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_4 (Dense)             (None, 128)               163968
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 20,133,218
# Trainable params: 5,075,827
# Non-trainable params: 15,057,391
# _________________________________________________________________

# %%
# Fine Tuning
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-6, momentum=0.9),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

history = model.fit(
      train_generator,                    
      epochs=1000,                              # tambahkan epochs jika akurasi model belum optimal
      validation_data=validation_generator,   # menampilkan akurasi pengujian data validasi
      callbacks = [checkpoint, early, callBack],
      verbose=2
)

# %% [markdown]
# # Test

# %%
from keras.models import load_model
model = load_model('/content/drive/MyDrive/Proyek Orbit/Model/mata-b4.h5')

# %%
import tensorflow as tf
from keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing import image
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
classes=['Bintitan', 'Konjungtivitis', 'Subconjunctival-Bleeding']

# %%
test_path = '/content/drive/MyDrive/Proyek Orbit/Dataset-Fix-Resize/test-mata/'

test_gen = ImageDataGenerator(
    # rescale=1/255.,
    # rotation_range=90,
    vertical_flip=True,
    # horizontal_flip=True,
    shear_range = 0.1,
    )

test_ds = test_gen.flow_from_directory(
    test_path, 
    target_size=(300, 300),
    batch_size=32,
    class_mode='categorical',
    shuffle=True, 
    )
# Out:
# Found 56 images belonging to 3 classes.

# %%
results = model.evaluate(test_ds)
print(f"test loss {results[0]}, test accuracy {results[1]}")
# Out:
# 2/2 [==============================] - 1s 463ms/step - loss: 0.3819 - accuracy: 0.8750
# test loss 0.3818661868572235, test accuracy 0.875

# %%
plt.figure(figsize=(10, 10))
x, label= test_ds.next()
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(x[i])
    result = np.where(label[i]==1)
    predict = model(tf.expand_dims(x[i], 0))
    score = tf.nn.softmax(predict[0])
    score_label = classes[np.argmax(score)]
    plt.title(f'Truth: {classes[result[0][0]]}\nPrediction:{score_label}')
    plt.axis(False)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #========================================================

# %%
test_path = '../input/4-animal-classification/test/test'
test_gen = image_datagen.flow_from_directory(    
    directory=test_path,
    target_size=(300, 300),
    batch_size=32,
    classes=['.'],
    shuffle=False,
)
# Out:
# Found 729 images belonging to 1 classes.

# %%
from PIL import Image
predict = []

# %%
import numpy as np
for i in range(1,730):
    img = Image.open('../input/4-animal-classification/test/test/'+str(i)+'.jpg')
    img = img.resize((300,300))
    c_predict = hypermodel.predict(np.asarray(img).reshape(-1,300,300,3))
    predict.append(c_predict)
    if(i % 100 == 0):
        print(i, "Predicted")
# Out:
# 100 Predicted
# 200 Predicted
# 300 Predicted
# 400 Predicted
# 500 Predicted
# 600 Predicted
# 700 Predicted

# %%
import pandas as pd
predictions = np.argmax(predict,axis=2)
submission_file = pd.read_csv("../input/4-animal-classification/Sample_submission.csv")
submission_file['Label'] = predictions
submission_file.to_csv('submission7.csv', index=False)
submission_file['Label'].value_counts()
# Out:
# 2    231
# 0    198
# 3    165
# 1    135
# Name: Label, dtype: int64

# %%
submission_file
# Out:
#       ID  Label
# 0      1      1
# 1      2      0
# 2      3      2
# 3      4      3
# 4      5      2
# ..   ...    ...
# 724  725      1
# 725  726      2
# 726  727      2
# 727  728      2
# 728  729      1
#
# [729 rows x 2 columns]

# %%
from keras.models import load_model

model.save('latest_my_model.h5')  # creates a HDF5 file 'my_model.h5'
# del model  # deletes the existing model

# returns a compiled model
# identical to the previous one
# model = load_model('my_model.h5')

# %%
import matplotlib.pyplot as plt

# %%
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('../input/4-animal-classification/test/test/1.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(rotation_range=20)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('../input/4-animal-classification/test/test/1.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(horizontal_flip='True')
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('../input/4-animal-classification/test/test/1.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(shear_range=20)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('../input/4-animal-classification/test/test/1.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(fill_mode='nearest')
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('../input/4-animal-classification/test/test/1.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(width_shift_range=0.2)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %%
# https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
# example of random rotation image augmentation
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
# load the image
img = load_img('../input/4-animal-classification/test/test/1.jpg')
# convert to numpy array
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(height_shift_range=0.1)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()
